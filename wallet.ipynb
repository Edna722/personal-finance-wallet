# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
bank_data = pd.read_csv(r"C:\Users\wanji\Desktop\Personal Finance Projects\bank+marketing\bank\bank-full.csv",  sep=';')
bank_data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
bank_data_2 = pd.read_csv(r"C:\Users\wanji\Desktop\Personal Finance Projects\bank+marketing\bank-additional\bank-additional\bank-additional-full.csv", sep = ';')
bank_data_2.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
# transactions_data = pd.read_csv(r"C:\Users\wanji\Desktop\Personal Finance Projects\archive (12)\credit_card_transactions-ibm_v2.csv")
# transactions_data

# %%
cards_data = pd.read_csv(r"C:\Users\wanji\Desktop\Personal Finance Projects\archive (12)\sd254_cards.csv")
cards_data
# Out:
#       User  CARD INDEX  Card Brand        Card Type       Card Number  \
# 0        0           0        Visa            Debit  4344676511950444
# 1        0           1        Visa            Debit  4956965974959986
# 2        0           2        Visa            Debit  4582313478255491
# 3        0           3        Visa           Credit  4879494103069057
# 4        0           4  Mastercard  Debit (Prepaid)  5722874738736011
# ...    ...         ...         ...              ...               ...
# 6141  1997           1        Amex           Credit   300609782832003
# 6142  1997           2        Visa           Credit  4718517475996018
# 6143  1998           0  Mastercard           Credit  5929512204765914
# 6144  1999           0  Mastercard            Debit  5589768928167462
# 6145  1999           1        Visa           Credit  4994011318343994
#
#       Expires  CVV Has Chip  Cards Issued Credit Limit Acct Open Date  \
# ...

# %%
users_data = pd.read_csv(r"C:\Users\wanji\Desktop\Personal Finance Projects\archive (12)\sd254_users.csv")
users_data
# Out:
#                  Person  Current Age  Retirement Age  Birth Year  Birth Month  \
# 0        Hazel Robinson           53              66        1966           11
# 1            Sasha Sadr           53              68        1966           12
# 2            Saanvi Lee           81              67        1938           11
# 3         Everlee Clark           63              63        1957            1
# 4         Kyle Peterson           43              70        1976            9
# ...                 ...          ...             ...         ...          ...
# 1995       Jose Faraday           32              70        1987            7
# 1996  Ximena Richardson           62              65        1957           11
# 1997     Annika Russell           47              67        1973            1
# 1998        Juelz Roman           66              60        1954            2
# 1999       Kenia Harris           21              60        1998           11
#
# ...

# %%
credit_transactions = pd.read_csv(r"C:\Users\wanji\Desktop\Personal Finance Projects\archive (12)\sd254_users.csv")
credit_transactions
# Out:
#                  Person  Current Age  Retirement Age  Birth Year  Birth Month  \
# 0        Hazel Robinson           53              66        1966           11
# 1            Sasha Sadr           53              68        1966           12
# 2            Saanvi Lee           81              67        1938           11
# 3         Everlee Clark           63              63        1957            1
# 4         Kyle Peterson           43              70        1976            9
# ...                 ...          ...             ...         ...          ...
# 1995       Jose Faraday           32              70        1987            7
# 1996  Ximena Richardson           62              65        1957           11
# 1997     Annika Russell           47              67        1973            1
# 1998        Juelz Roman           66              60        1954            2
# 1999       Kenia Harris           21              60        1998           11
#
# ...

# %%
# Understanding the business case 
# Merge the datasets 
transaction_dataset = pd.merge(users_data, credit_transactions, on = 'Person', how = 'outer')
transaction_dataset
# Out:
#                  Person  Current Age_x  Retirement Age_x  Birth Year_x  \
# 0        Hazel Robinson             53                66          1966
# 1        Hazel Robinson             53                66          1966
# 2        Hazel Robinson             67                60          1952
# 3        Hazel Robinson             67                60          1952
# 4            Sasha Sadr             53                68          1966
# ...                 ...            ...               ...           ...
# 2009       Jose Faraday             32                70          1987
# 2010  Ximena Richardson             62                65          1957
# 2011     Annika Russell             47                67          1973
# 2012        Juelz Roman             66                60          1954
# 2013       Kenia Harris             21                60          1998
#
#       Birth Month_x Gender_x               Address_x  Apartment_x  \
# ...

# %% [markdown]
# ## Data Cleaning/Munging

# %%
transaction_dataset =
